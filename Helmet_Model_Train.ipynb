# %% [markdown]
# # INTRO AND DATASET

# %%
# !pip install roboflow #1qhric2TfMP08MJP0i6Q
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 78.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 139.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from roboflow import Roboflow

# %%
rf = Roboflow(api_key="1qhric2TfMP08MJP0i6Q")
# bike-helmet-detection-2vdjo-6sh9n
# Replace these with your workspace and project names
project = rf.workspace("dakshs-space").project("bike-helmet-detection-2vdjo-6sh9n")

# If you have multiple versions, change the version number below
dataset = project.version(4).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Bike-Helmet-Detection-4 in yolov8:: 100%|██████████| 9942/9942 [00:01<00:00, 8345.00it/s]

# %% [markdown]
# # Model

# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 30.7 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Load pretrained YOLOv8s model
model = YOLO("yolov8s.pt")

# %%
results = model.train( #
    data="/content/Bike-Helmet-Detection-4/data.yaml",  # Path to dataset YAML
    epochs=30,       # Increase if you want more training
    imgsz=800,       # Image size (640 is standard)
    batch=8,         # You can tweak this based on GPU memory
    name="helmet_yolov8_run",  # Folder name for saving results
)
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val(data='/content/Bike-Helmet-Detection-4/data.yaml', split='test')
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 849.9±143.3 MB/s, size: 27.2 KB)
# val: Scanning /content/Bike-Helmet-Detection-4/test/labels... 232 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 232/232 2.5Kit/s 0.1s
# val: New cache created: /content/Bike-Helmet-Detection-4/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 15/15 2.3it/s 6.4s
#                    all        232        570      0.928      0.889      0.937      0.747
#            With Helmet        174        375      0.975      0.926      0.979       0.78
#         Without Helmet         94        195      0.882      0.851      0.896      0.713
# Speed: 3.8ms preprocess, 13.8ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to /content/runs/detect/val2

# %%
from google.colab import files
files.download('/content/runs/detect/helmet_yolov8_run/weights/best.pt')
