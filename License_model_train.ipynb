# %%
# !pip install roboflow #1qhric2TfMP08MJP0i6Q
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 87.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 103.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from roboflow import Roboflow

# %%
rf = Roboflow(api_key="1qhric2TfMP08MJP0i6Q")
# bike-helmet-detection-2vdjo-6sh9n
# Replace these with your workspace and project names
project = rf.workspace("dakshs-space").project("license-prediction-yfedd") #

# If you have multiple versions, change the version number below
dataset = project.version(2).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov8 in progress : 85.0%
# Version export complete for yolov8 format
# ...
# Extracting Dataset Version Zip to license-prediction-2 in yolov8:: 100%|██████████| 4472/4472 [00:01<00:00, 4146.71it/s]

# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 53.2 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolov8s.pt")

# %%
results = model.train( #
    data="/content/license-prediction-2/data.yaml",  # Path to dataset YAML
    epochs=30,       # Increase if you want more training
    imgsz=960,       # Image size (640 is standard)
    batch=8,         # You can tweak this based on GPU memory
    name="plate_yolov8_run",  # Folder name for saving results
)
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val(data='/content/license-prediction-2/data.yaml', split='test')
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 22.8±10.1 MB/s, size: 58.8 KB)
# val: Scanning /content/license-prediction-2/test/labels... 123 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 123/123 539.3it/s 0.2s
# val: New cache created: /content/license-prediction-2/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.4it/s 5.7s
#                    all        123        124      0.975      0.976      0.991      0.946
# Speed: 8.2ms preprocess, 20.2ms inference, 0.0ms loss, 2.8ms postprocess per image
# Results saved to /content/runs/detect/val2

# %%
from google.colab import files
files.download('/content/runs/detect/plate_yolov8_run/weights/best.pt')
